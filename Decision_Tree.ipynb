# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi050/Machine_Learning/blob/master/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Position_Salaries.csv")
x=df.iloc[:,1:2].values
y=df.iloc[:,2].values

# %%
#Fitting the DEcision Tree Regression in the datset
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(criterion="mse",random_state=0)
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
a=np.array([6.5])
pred=regressor.predict(a.reshape(-1,1))
print(pred)
# Out:
# [150000.]

# %%
#Visualizing the data and the result
plt.scatter(x,y,color="red")
plt.plot(x,regressor.predict(x),color="blue")
plt.title("Truth or Bluff (Decision Tree Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
#the above almost prefect graph means there is somehting is wrong in the code or algo.
#the algo si thaking the average prediction between the intervals
#hence the between the intervals, there is a straight line
#it is non linear and non continous

# %%
#Visualising the real decision tree
x_grid=np.arange(min(x),max(x),0.00001)
x_grid = x_grid.reshape(len(x_grid),1)
plt.scatter(x,y,color="red")
plt.plot(x_grid,regressor.predict(x_grid),color="blue")
plt.title("Truth or Bluff (Decision Tree Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()
