# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi050/Machine_Learning/blob/master/SVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the dataset
df = pd.read_csv("Position_Salaries.csv")
x= df.iloc[:,1:2].values
y= df.iloc[:,2].values

# %%
#Feature SCaling need to be done manually.
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
sc_y=StandardScaler()
x=sc_x.fit_transform(x)
y=sc_y.fit_transform(y.reshape(-1,1))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#Fitting the data
from sklearn.svm import SVR
regressor = SVR(kernel="rbf")
regressor.fit(x,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#predicting new result for manual input
a=np.array([6.5])
pred=sc_y.inverse_transform(regressor.predict(sc_x.transform(a.reshape(-1,1))))
print(pred)
# Out:
# [252789.13921624]

# %%
plt.scatter(x,y,color = "red")
plt.plot(x,regressor.predict(x),color = "blue")
plt.title("TRUTH OR BLUFF(SVR)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
#Visualization for higher and smoother curve
x_grid=np.arange(min(x),max(x),0.01)
x_grid=x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color="red")
plt.plot(x_grid,regressor.predict(x_grid),color="blue")
plt.title("TRUTH OR BLUFF(SVR)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()
